# %%
import re
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
from utils3d import *
# %matplotlib inline
from IPython.display import display

# %%
os.chdir('../downloads')
FILE_PATH = 'SMP04I-0d0p-1600x1600x1700-16b.raw'
FILE_PATH_M = 'SMP04I-0d0p-1600x1600x1700-16b-Mask.raw'

# %%
#read data
img_arr = read_raw(FILE_PATH)
img_arr_m = read_raw(FILE_PATH_M)

# %%
plot_image(convert_to_float(crop_image(img_arr[100,:,:])))

# %%
#overlay two images
i = np.random.randint(0,img_arr.shape[0])
img, msk = convert_to_float(img_arr[i,:,:]),convert_to_float(img_arr_m[i,:,:])
plot_image(overlay_mask(img,.8,msk,.2,mask_color_rgb=(1,0,0)))
plot_image(img)

# %%
for im in quadrants(img_arr[1,:,:]):
    print(im.shape)
    plot_image(im)

# %%
for fp in ['SMP04F-0d0p-1600x1600x1700-16b.raw','SMP04I-0d0p-1600x1600x1700-16b.raw','SMP04I-0d0p-1600x1600x1700-16b-Mask.raw']:
    cut_and_save(fp,cut='quad',eight_bit=True)
