# %%
import re
import os
import numpy as np
import matplotlib.pyplot as plt
import cv2
import utils3d

# %%
os.chdir('../downloads')
FILE_PATH = 'SMP04I-0d0p-1600x1600x1700-16b-Mask.raw'

# %%
#read data
img_arr = utils3d.read_raw(FILE_PATH)

# %%
#plot any image
utils3d.plot_slice(utils3d.crop_image(img_arr),np.random.randint(0,1700))

# %%
utils3d.plot_image(img_arr[1,:,:])
for im in utils3d.quadrants(img_arr[1,:,:]):
    print(im.shape)
    utils3d.plot_image(im)
# Out:
# (880, 880)
# (880, 880)
# (880, 880)
# (880, 880)

# %%
for fp in ['SMP04F-0d0p-1600x1600x1700-16b.raw','SMP04I-0d0p-1600x1600x1700-16b.raw','SMP04I-0d0p-1600x1600x1700-16b-Mask.raw']:
    utils3d.cut_and_save(fp,cut='quad',eight_bit=True)
